# %%
from pathlib import Path
import pandas as pd

df = pd.read_parquet(Path('/home/gderijck/detection/data/raw/llm_added.parquet'))

df.head()
# Out:
#        _id source                                           keywords  year  \
# 0  8551798     UG                                                 []  2018
# 1  3199491     UG  [categorisering, werklast bestuurders, verkeer...  2013
# 2  3199532     UG  [Duurzame mobiliteit, STOP-principe, co-modali...  2013
# 3  3189619     UG  [overactivatie, perceptie, motor area, ontwikk...  2012
# 4  3208431     UG  [Theo Van Rysselberghe, James Ensor, artists' ...  2013
#
#                                             abstract  \
# 0  Familiale adenomateuze polypose (FAP) is een z...
# 1  Snelheid is een belangrijke ongevalsfactor. Sn...
# 2  Zuiniger voertuigen op niet-klassieke brandsto...
# 3  Vloeiende spraak wordt bekomen wanneer de corr...
# 4  Tijdens de negentiende eeuw was de spiegel een...
#
#                                    abstract_sentence  \
# 0  [Familiale adenomateuze polypose (FAP) is een ...
# 1  [Snelheid is een belangrijke ongevalsfactor., ...
# ...

# %%
df.columns
# Out:
# Index(['_id', 'source', 'keywords', 'year', 'abstract', 'abstract_sentence',
#        'qwen3.6:27b_single', 'gemma4:e4b_single', 'qwen3.5:4b_single',
#        'gemma4:26b_single', 'qwen3.6:27b_full', 'gemma4:e4b_full',
#        'qwen3.5:4b_full', 'gemma4:26b_full', 'gemma4:26b_25', 'gemma4:26b_50',
#        'gemma4:26b_75', 'gemma4:e4b_25', 'gemma4:e4b_50', 'gemma4:e4b_75',
#        'qwen3.5:4b_25', 'qwen3.5:4b_50', 'qwen3.5:4b_75', 'qwen3.6:27b_25',
#        'qwen3.6:27b_50', 'qwen3.6:27b_75'],
#       dtype='object')
